# %%
print("testing")
# Out:
# testing

# %%
# %pwd
# Out:
# 'c:\\Users\\Natasha\\OneDrive\\Documents\\Practice\\data-med'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Natasha\\OneDrive\\Documents\\Practice'
